# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
mart = pd.read_excel('supermarket_sales.xlsx')
mart.head(10)
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
# 5  371-85-5789      B  Mandalay        Normal    Male       Health_and_beauty
# 6  273-16-6619      B  Mandalay        Normal    Male      Home_and_lifestyle
# 7  649-29-6775      B  Mandalay        Normal    Male     Fashion_accessories
# 8  145-94-9061      B  Mandalay        Normal  Female      Food_and_beverages
# 9  871-79-8483      B  Mandalay        Normal    Male     Fashion_accessories
#
#    Unit price  Quantity   Tax 5%     Total                 Date      Time  \
# ...

# %%
mart.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
mart.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# <font size="8">Categorical_Plots</font>

# %%
sns.countplot(x = mart['Product line'])
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize=(7,4))
sns.countplot(x = mart['Product line'])
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='count'>

# %%
sns.countplot(y = mart['Product line'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='Product line'>

# %%
sns.countplot(x = mart['Product line'], hue = mart['Gender'])
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='count'>

# %%
sns.countplot(y = mart['Product line'], hue = mart['Gender'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='Product line'>

# %%
sns.boxplot(y = 'Total', data = mart, width= 0.2)
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
sns.boxplot(y = 'Total',x = 'Payment', data = mart)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.boxplot(y = 'Total',x = 'Payment', data = mart, hue = 'Gender')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.boxplot(y = 'Total',x = 'Payment', data = mart, hue = 'Gender', showmeans = True)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
plt.figure(figsize=(10,7))
sns.boxplot(data = mart)
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(data = mart, y = 'Total')
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
sns.violinplot(data = mart, y = 'Total', x = 'Payment')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.violinplot(data = mart, y = 'Total', x = 'Payment', hue = 'Gender')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.violinplot(data = mart, y = 'Total', x = 'Payment', hue = 'Gender', split=True)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.violinplot(data = mart, y = 'Total', x = 'Payment', hue = 'Gender', split=True, inner = 'quartile')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.violinplot(data = mart, y = 'Total', x = 'Payment', hue = 'Gender', split=True, inner = 'quartile', bw = 0.1)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.stripplot(data = mart, x = 'Total')
# Out:
# <AxesSubplot:xlabel='Total'>

# %%
sns.stripplot(data = mart, x = 'Total', jitter = 0.2)
# Out:
# <AxesSubplot:xlabel='Total'>

# %%
sns.stripplot(data = mart, x = 'Total', linewidth=0.7)
# Out:
# <AxesSubplot:xlabel='Total'>

# %%
sns.stripplot(data = mart, x = 'Total',y = 'Payment', linewidth=0.7, jitter = 0.3)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Payment'>

# %%
sns.stripplot(data = mart, x = 'Total',y = 'Payment', hue = 'Gender',linewidth=0.7, jitter = 0.2)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Payment'>

# %%
sns.stripplot(data = mart, x = 'Total',y = 'Payment', hue = 'Gender',linewidth=0.7, jitter = 0.2, dodge= True)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Payment'>

# %%
sns.stripplot(data = mart, y = 'Total', x = 'Payment', linewidth=0.8)
sns.violinplot(data = mart, y = 'Total', x = 'Payment', color = 'gray')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.swarmplot(data = mart, y = 'Total')
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
sns.swarmplot(data = mart, y = 'Total', x = 'Payment')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.swarmplot(data = mart, y = 'Total', x = 'Payment', hue = 'Gender')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.swarmplot(data = mart, y = 'Total', x = 'Payment', hue = 'Gender', split = True)
# Out:
# c:\Users\Computador\anaconda3\lib\site-packages\seaborn\categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# c:\Users\Computador\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Computador\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Computador\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 13.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
plt.figure(figsize=(10,7))
sns.swarmplot(data = mart, y = 'Total', x = 'Payment')
sns.violinplot(data = mart, y = 'Total', x = 'Payment', color = 'gray')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.catplot(data = mart, x = 'Payment', y = 'Total', kind = 'swarm')

# %% [markdown]
# <font size="8">Distribution Plots</font>

# %%
sns.histplot(data = mart, x = 'Total')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(data = mart, x = 'Total', bins = 60)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(data = mart, x = 'Total', bins = 60, kde = True)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(data = mart, x = 'Total', hue = 'Payment')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(data = mart, x = 'Total', hue = 'Payment', multiple = 'stack')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(data = mart, x = 'Total', hue = 'Payment', element = 'poly')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
#to see number of each variable
sns.histplot(data = mart, x = 'Payment')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Count'>

# %%
sns.histplot(data = mart, x = 'Payment', shrink = 0.7)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Count'>

# %%
sns.histplot(data = mart, x = 'Total', stat = 'probability')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Probability'>

# %%
#to see a bivariate histogram
sns.histplot(data = mart, x = 'Total', y = 'gross income')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='gross income'>

# %%
sns.kdeplot(data = mart, x = 'Total')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Density'>

# %%
sns.kdeplot(data = mart)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(data = mart, x = 'Total',bw_adjust=10)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Density'>

# %%
sns.kdeplot(data = mart, x = 'Total',bw_adjust=0.3)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Density'>

# %%
sns.kdeplot(data = mart, x='Total', hue = 'Payment', bw_adjust=0.5)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Density'>

# %%
sns.kdeplot(data=mart, x = 'Total', hue='Payment', multiple='stack')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Density'>

# %%
sns.kdeplot(data=mart, x='Total', log_scale=True)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Density'>

# %%
sns.kdeplot(data=mart,x='Total',hue='Payment', palette='Dark2', multiple='stack', linewidth = 1.5)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Density'>

# %%
#bivariado
sns.kdeplot(data=mart,x='Unit price', y='gross income')
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='gross income'>

# %%
sns.kdeplot(data=mart,x='Unit price', y='gross income',hue='Gender')
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='gross income'>

# %%
sns.kdeplot(data=mart,x='Unit price', y='gross income',hue='Gender', fill=True)
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='gross income'>

# %%
sns.kdeplot(data=mart,x='Unit price', y='gross income',hue='Gender', fill=True, levels = 5)
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='gross income'>

# %%
#RUG PLOT, plot the marginal distributions by drawing ticks along the x and y axes
#this function is intended to complement other plots by showing the location of individual observations in an unobstrusive way

# %%
plt.figure(figsize=(15,5))
sns.rugplot(data = mart, x = 'Unit price', y='gross income')
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='gross income'>

# %%
plt.figure(figsize=(15,5))
sns.rugplot(data = mart, x = 'Unit price', y='gross income', hue='Gender')
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='gross income'>

# %%
plt.figure(figsize=(15,7))
sns.rugplot(data = mart, x = 'Unit price', y='gross income', hue='Gender', height=0.1)
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='gross income'>

# %%
plt.figure(figsize=(15,7))
sns.kdeplot(data = mart, x='Unit price', y='gross income', hue ='Gender', fill = True)
sns.rugplot(data = mart, x='Unit price', y='gross income', hue ='Gender')
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='gross income'>

# %%
plt.figure(figsize=(15,7))
sns.rugplot(data=mart, x= 'Unit price', y='gross income', hue = 'Gender')
sns.scatterplot(data=mart, x= 'Unit price', y='gross income', hue = 'Gender')
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='gross income'>

# %%
plt.figure(figsize=(15,7))
sns.kdeplot(data = mart, x='Unit price', y='gross income', hue ='Gender', fill = True)
sns.rugplot(data = mart, x='Unit price', y='gross income', hue ='Gender', height=-0.01, clip_on=False)
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='gross income'>
